# %% [markdown]
# ### Fill variables in the next cell & Run the notebook

# %%
search_entry = 'یک گربه'
video_name = 'ALL'

# %%
import requests
import base64
import io
from PIL import Image

def string_to_image(base64_string):
    image_data = base64.b64decode(base64_string)
    image_stream = io.BytesIO(image_data)
    return Image.open(image_stream)

response = requests.get(f"https://inference-server-mlsd-video-search.darkube.app/{video_name}?search_entry={search_entry}")
if not response.ok:
    raise Exception(f"Request failed. response: {response.raw}, status code: {response.status_code}, reason: {response.request}")
for record in response.json():
    print(f"score: {record['score']}, video name: {record['video_name']}, second: {record['second']}")
    display(string_to_image(record['image_base64']))
# Out:
# score: 0.39969727, video name: AroundTheWorldIn80Days, second: 35
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# score: 0.33941245, video name: AroundTheWorldIn80Days, second: 10
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# score: 0.32559, video name: AroundTheWorldIn80Days, second: 15
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# score: 0.28324407, video name: AroundTheWorldIn80Days, second: 20
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# score: 0.25850052, video name: AroundTheWorldIn80Days, second: 95
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# score: 0.25269732, video name: AroundTheWorldIn80Days, second: 5
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# score: 0.24507967, video name: AroundTheWorldIn80Days, second: 25
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# score: 0.22990964, video name: AroundTheWorldIn80Days, second: 40
# ...
